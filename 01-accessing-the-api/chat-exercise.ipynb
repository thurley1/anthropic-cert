# %% [markdown]
# # Chat Bot Exercise
#
# Make a chat bot using the three helper functions from the last lesson:
#
# 1. Prompt the user for input using the built-in `input()` function
# 2. Add it to a list of messages
# 3. Call the API
# 4. Add the generated text to the list of messages
# 5. Print the generated text
# 6. Repeat from #1
#
# **Two practical notes for running in a notebook:**
# - `input()` works fine here — VS Code / Jupyter pops an input box at the **top of the window**. Click it, type, press Enter.
# - Step 6 says "repeat", i.e. an infinite loop. Add an **exit condition** (e.g. the user types `quit`) so you can stop cleanly. If you ever get stuck in a running loop, use **Interrupt** (the ⏹ / stop button on the cell, or Kernel → Interrupt).

# %% [markdown]
# ## Setup + helpers (from the multi-turn lesson)

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-5"


def get_text(message):
    for block in message.content:
        if block.type == "text":
            return block.text
    return ""


def add_user_message(messages, text):
    messages.append({"role": "user", "content": text})

def add_assistant_message(messages, text):
    messages.append({"role": "assistant", "content": text})

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return get_text(message)


print("Ready. Helpers loaded.")
# Out:
# Ready. Helpers loaded.

# %% [markdown]
# ## Your turn — build the chat bot
#
# Fill in the loop below. Ping me when you want it reviewed.

# %%
messages = []

while True:
    # 1. Prompt the user for input
    user_input = input("You: ")

    # Exit condition so we can stop the loop cleanly
    if user_input.strip().lower() in ("quit", "exit"):
        print("Goodbye!")
        break

    # 2. Add it to the list of messages
    add_user_message(messages, user_input)

    # 3. Call the API
    answer = chat(messages)

    # 4. Add the generated text to the list of messages
    add_assistant_message(messages, answer)

    # 5. Print the generated text
    print(f"Claude: {answer}\n")

    # 6. Repeat from #1 (the while loop does this automatically)
# Out:
# Claude: # 1 + 1 = 2
#
# This is a basic arithmetic addition. When you combine 1 unit with another 1 unit, you get a total of 2 units.
#
# Claude: # 2 + 2 = 4
#
# Adding 2 to the previous result (2) gives you 4.
#
# Goodbye!
