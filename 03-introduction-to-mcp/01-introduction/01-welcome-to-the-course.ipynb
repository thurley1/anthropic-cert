# %% [markdown]
# # Welcome to the Course
#
# **Introduction to Model Context Protocol (MCP)** — course 3 of 4 in the CPN path.
#
# MCP is an open standard for connecting AI applications to the tools, data, and context they need. Instead of every app hand-rolling a bespoke integration for every data source, MCP defines **one protocol** that any client (Claude Desktop, Claude Code, your own app) can speak to any server (a wrapper around a database, an API, a filesystem, etc.). Build the server once; every MCP-aware client can use it.

# %% [markdown]
# ## What this course covers
#
# | Section | Lessons |
# |---------|---------|
# | **Introduction** | Welcome · Introducing MCP · MCP clients |
# | **Hands-on with MCP servers** | Project setup · Defining tools with MCP · The server inspector |
# | **Connecting with MCP clients** | Implementing a client · Defining resources · Accessing resources · Defining prompts · Prompts in the client |
# | **Assessment & wrap-up** | Final assessment · MCP review |
#
# By the end you'll have built a working MCP **server** (exposing tools, resources, and prompts) and a **client** that connects to it — the two halves of the protocol.

# %% [markdown]
# ## Prerequisites & setup
#
# This repo already has a shared environment set up (see the root [`README.md`](../../README.md)):
#
# - **`.venv`** — shared virtualenv, kernel *"Python (anthropic-cert)"*.
# - **`.env`** (gitignored) — holds `ANTHROPIC_API_KEY`.
# - **`requirements.txt`** already includes **`mcp[cli]`** (the Python MCP SDK + CLI) and `prompt-toolkit`.
#
# The course uses **`uv`** as its package/runtime manager for MCP projects — a fast Python package manager. Install guide: **https://docs.astral.sh/uv/**
#
# > **✅ `uv` is installed** (v0.11.28, at `C:\Users\thurl\.local\bin`). Gotcha: the installer adds that dir to PATH, but **already-open terminals won't see it** — open a fresh terminal, or run `$env:Path = "C:\Users\thurl\.local\bin;$env:Path"` in the current one. Verify with `uv --version`.
# >
# > **`uv` vs. the shared `.venv`:** the course's `uv run server.py` / `uv run mcp dev server.py` work as-is. If you'd rather use the repo's existing `.venv` (already has `mcp[cli]`), translate: `uv run X` → `.\.venv\Scripts\python.exe X`, and `uv run mcp ...` → `mcp ...`.
#
# > **Note — we already did MCP once.** Course 1 included a full MCP section: [`../building-with-the-claude-api/07-mcp/`](../building-with-the-claude-api/07-mcp) with a `cli-project` starter + `cli-project-complete` answer key. This dedicated course goes **deeper/broader** — resources and prompts (not just tools), the inspector, and a hand-written client.

# %% [markdown]
# ## Reference links
#
# - **MCP introduction (official):** https://modelcontextprotocol.io/introduction
# - **UV install guide:** https://docs.astral.sh/uv/
#
# > The lesson page also has an **"Open in Claude"** button — it launches the exercise scaffold directly in Claude so you can follow along hands-on.
#
# Next: **Introducing MCP** — the problem MCP solves and the client/server architecture.
